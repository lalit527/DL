# %%
import pandas as pd

# %%
df = pd.read_csv('submission-2.csv')

# %%
df.head()
# Out:
#                                  id  affenpinscher  afghan_hound  \
# 0  a4e7a39658ee317d06b7d5aa5fcca6ec   2.667869e-07  4.744099e-07
# 1  265351eb33caaff9e9892333cb6fdb2a   1.463389e-07  4.663432e-07
# 2  71665f454ef0c082c6d21d414441af30   3.052857e-07  6.533731e-07
# 3  385cf6904272259c0edc8882df482cfa   9.323776e-10  8.137706e-11
# 4  ce78ed744ec263c8ea7418e75959dfff   1.507997e-07  6.224893e-06
#
#    african_hunting_dog      airedale  american_staffordshire_terrier  \
# 0         1.959881e-07  3.218170e-06                    6.794121e-06
# 1         4.027507e-08  3.049954e-08                    4.389210e-09
# 2         1.402038e-08  2.842654e-07                    9.478725e-08
# 3         2.107981e-09  4.723710e-09                    9.226142e-10
# 4         1.974884e-08  5.320984e-07                    9.387873e-07
#
#     appenzeller  australian_terrier       basenji        basset  \
# 0  6.327816e-05        2.830008e-08  4.833056e-09  3.009610e-08
# ...

# %%
len(df)
# Out:
# 20714

# %%
df[df['id'] == 'a4e7a39658ee317d06b7d5aa5fcca6ec']
# Out:
#                                      id  affenpinscher  afghan_hound  \
# 0      a4e7a39658ee317d06b7d5aa5fcca6ec   2.667869e-07  4.744099e-07
# 10357  a4e7a39658ee317d06b7d5aa5fcca6ec   2.667874e-07  4.744068e-07
#
#        african_hunting_dog  airedale  american_staffordshire_terrier  \
# 0             1.959881e-07  0.000003                        0.000007
# 10357         1.959890e-07  0.000003                        0.000007
#
#        appenzeller  australian_terrier       basenji        basset  \
# 0         0.000063        2.830008e-08  4.833056e-09  3.009610e-08
# 10357     0.000063        2.830027e-08  4.833053e-09  3.009590e-08
#
#              ...            toy_poodle   toy_terrier        vizsla  \
# 0            ...          3.791759e-09  1.216303e-09  1.800823e-07
# 10357        ...          3.791742e-09  1.216309e-09  1.800826e-07
#
#        walker_hound    weimaraner  welsh_springer_spaniel  \
# 0      2.797356e-07  1.893280e-07            2.578589e-07
# ...

# %%
df.drop(df.index[df.index >= 10357], inplace=True, axis=0)

# %%
df.index[df.index >= 10357]
# Out:
# Int64Index([10357, 10358, 10359, 10360, 10361, 10362, 10363, 10364, 10365,
#             10366,
#             ...
#             20704, 20705, 20706, 20707, 20708, 20709, 20710, 20711, 20712,
#             20713],
#            dtype='int64', length=10357)

# %%
len(df)
# Out:
# 10357

# %%
df.to_csv('submission-correct2.csv', index=False)

# %%
df.loc[0]
# Out:
# id                                a4e7a39658ee317d06b7d5aa5fcca6ec
# affenpinscher                                          2.66787e-07
# afghan_hound                                            4.7441e-07
# african_hunting_dog                                    1.95988e-07
# airedale                                               3.21817e-06
# american_staffordshire_terrier                         6.79412e-06
# appenzeller                                            6.32782e-05
# australian_terrier                                     2.83001e-08
# basenji                                                4.83306e-09
# basset                                                 3.00961e-08
# beagle                                                 2.17862e-07
# bedlington_terrier                                     1.48704e-08
# bernese_mountain_dog                                   0.000381656
# black-and-tan_coonhound                                3.56654e-08
# ...

# %%
df.
