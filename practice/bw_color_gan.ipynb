# %%
import fastai
from fastai.vision import *
from fastai.callbacks import *
from fastai.vision.gan import *

# %%
path = untar_data(URLs.PETS)
path_hr = path/'images'
path_lr = path/'crappy'
path_bw = path/'bw'

# %%
from PIL import Image, ImageDraw, ImageFont

class crappifier(object):
    def __init__(self, path_lr, path_hr):
        self.path_lr = path_lr
        self.path_hr = path_hr              
        
    def __call__(self, fn, i):       
        dest = self.path_lr/fn.relative_to(self.path_hr)    
        dest.parent.mkdir(parents=True, exist_ok=True)
        img = PIL.Image.open(fn)
        targ_sz = resize_to(img, 96, use_min=True)
        img = img.resize(targ_sz, resample=PIL.Image.BILINEAR).convert('RGB')
        w,h = img.size
        q = random.randint(10,70)
        ImageDraw.Draw(img).text((random.randint(0,w//2),random.randint(0,h//2)), str(q), fill=(255,255,255))
        img.save(dest, quality=q)

# %%
from PIL import Image

class BlackNWhite(object):
    def __init__(self, path_lr, path_hr):
        self.path_lr = path_lr
        self.path_hr = path_hr              
        
    def __call__(self, fn, i):       
        dest = self.path_lr/fn.relative_to(self.path_hr)    
        dest.parent.mkdir(parents=True, exist_ok=True)
        img = PIL.Image.open(fn)
        bw = img.convert('L')
        bw.save(dest)

# %%
 
def black_and_white(input_image_path, output_image_path):
    name = input_image_path.name
    (output_image_path).mkdir(parents=True, exist_ok=True)
    color_image = Image.open(input_image_path)
    bw = color_image.convert('L')
    bw.save(output_image_path/name)

# %%
files = get_image_files(path/'images')
files[:4]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_71.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_136.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_64.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Bengal_193.jpg')]

# %%
files[0].name
# Out:
# 'japanese_chin_71.jpg'

# %%
(path/'bnw').mkdir(parents=True, exist_ok=True)

# %%
black_and_white(files[0], path/'bnw/test.jpg')

# %%
img = Image.open(path/'bnw/test.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=337x500 at 0x7FC072DA9390>

# %%
img = Image.open(files[0])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=337x500 at 0x7FC072DA94A8>

# %%
il = ImageList.from_folder(path_hr)
parallel(BlackNWhite(path_bw, path_hr), il.items)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7390' class='' max='7390', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [7390/7390 01:00<00:00]
#     </div>

# %%
bw_files = get_image_files(path_bw)
bw_files[:4]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/bw/japanese_chin_71.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/bw/great_pyrenees_136.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/bw/japanese_chin_64.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/bw/Bengal_193.jpg')]

# %%
img = Image.open(bw_files[0])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=337x500 at 0x7FC05C5D0D30>

# %%
bs,size=32, 128
arch = models.resnet34

# %%
arch = models.resnet34
src = ImageImageList.from_folder(path_bw).split_by_rand_pct(0.1, seed=42)

# %%
def get_data(bs,size):
    data = (src.label_from_func(lambda x: path_hr/x.name)
           .transform(get_transforms(max_zoom=2.), size=size, tfm_y=True)
           .databunch(bs=bs).normalize(imagenet_stats, do_y=True))

    data.c = 3
    return data

# %%
data_gen = get_data(bs,size)

# %%
data_gen.show_batch(4)

# %%
data_gen.show_batch(4, ds_type=DatasetType.Valid)

# %%
wd = 1e-3

y_range = (-3.,3.)

# %%
loss_gen = MSELossFlat()

# %%
def create_gen_learner():
    return unet_learner(data_gen, arch, wd=wd, blur=False, norm_type=NormType.Weight,
                        self_attention=True, y_range=y_range, loss_func=loss_gen)

# %%
learn_gen = create_gen_learner()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 100855538.56it/s]

# %%
learn_gen.fit_one_cycle(2, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.110116</td>
#       <td>0.096703</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.094268</td>
#       <td>0.088770</td>
#       <td>03:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(3, slice(1e-6,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.093001</td>
#       <td>0.092451</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.084412</td>
#       <td>0.085824</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.085142</td>
#       <td>0.083801</td>
#       <td>03:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.show_results(rows=4)

# %%
learn_gen.save('gen-pre2')

# %%
learn_gen.load('gen-pre2');

# %%
name_gen = 'image_gen'
path_gen = path/name_gen

# %%
path_gen.mkdir(exist_ok=True)

# %%
def save_preds(dl):
    i = 0
    names = dl.dataset.items
    
    for b in dl:
        preds = learn_gen.pred_batch(batch=b, reconstruct=True)
        for o in preds:
            o.save(path_gen/names[i].name)
            i += 1

# %%
save_preds(data_gen.fix_dl)

# %%
PIL.Image.open(path_gen.ls()[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x7FC072F2D3C8>

# %%
learn_gen=None
gc.collect()
# Out:
# 7

# %%
def get_crit_data(classes, bs, size):
    src = ImageList.from_folder(path, include=classes).split_by_rand_pct(0.1, seed=42)
    ll = src.label_from_folder(classes=classes)
    data = (ll.transform(get_transforms(max_zoom=2.), size=size)
           .databunch(bs=bs).normalize(imagenet_stats))
    data.c = 3
    return data

# %%
data_crit = get_crit_data([name_gen, 'images'], bs=bs, size=size)

# %%
data_crit.show_batch(rows=3, ds_type=DatasetType.Train, imgsize=3)

# %%
loss_critic = AdaptiveLoss(nn.BCEWithLogitsLoss())

# %%
def create_critic_learner(data, metrics):
    return Learner(data, gan_critic(), metrics=metrics, loss_func=loss_critic, wd=wd)

# %%
learn_critic = create_critic_learner(data_crit, accuracy_thresh_expand)

# %%
learn_critic.fit_one_cycle(6, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh_expand</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.272930</td>
#       <td>0.210106</td>
#       <td>0.926952</td>
#       <td>07:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.142482</td>
#       <td>0.122726</td>
#       <td>0.960085</td>
#       <td>06:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.122188</td>
#       <td>0.089217</td>
#       <td>0.972991</td>
#       <td>06:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.092049</td>
#       <td>0.064280</td>
#       <td>0.979117</td>
#       <td>06:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.070610</td>
#       <td>0.050789</td>
#       <td>0.983533</td>
#       <td>06:49</td>
#     </tr>
#     <tr>
# ...

# %%
learn_critic.save('critic-pre2')

# %%
learn_crit=None
learn_gen=None
gc.collect()
# Out:
# 20685

# %%
data_crit = get_crit_data(['bw', 'images'], bs=bs, size=size)

# %%
learn_crit = create_critic_learner(data_crit, metrics=None).load('critic-pre2')

# %%
learn_gen = create_gen_learner().load('gen-pre2')

# %%
switcher = partial(AdaptiveGANSwitcher, critic_thresh=0.65)
learn = GANLearner.from_learners(learn_gen, learn_crit, weights_gen=(1.,50.), show_img=False, switcher=switcher,
                                 opt_func=partial(optim.Adam, betas=(0.,0.99)), wd=wd)
learn.callback_fns.append(partial(GANDiscriminativeLR, mult_lr=5.))

# %%
lr = 1e-4

# %%
learn.fit(40,lr)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='40', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [8/40 56:07<3:44:30]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>gen_loss</th>
#       <th>disc_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
learn.save('gan-1c')

# %%
learn.data=get_data(16,192)

# %%
learn.fit(10,lr/2)

# %%
learn.show_results(rows=16)
